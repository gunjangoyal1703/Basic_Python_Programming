# %% [markdown]
# # Study_Pandas_library
# ## Experiment - 9

# %% [markdown]
# ### Gunjan Goyal
# ### 25070123048
# ### E&TC-A3

# %%
import pandas as pd
s = pd.Series([10,20,30,40])
print(s)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# dtype: int64

# %%
# Create DataFrame
data={
    "Name":["A","B","C"],
    "Marks":[85,90,78]
}
df = pd.DataFrame(data)
df
# Out:
#   Name  Marks
# 0    A     85
# 1    B     90
# 2    C     78

# %%
df.head() # Gives first 5 entries
df.tail() # Gives last 5 entries

# %%
df.shape
# Out:
# (3, 2)

# %%
df.ndim # Gives number of columns
# Out:
# 2

# %%
df.size
# Out:
# 6

# %%
# Display Column Names
df.columns
# Out:
# Index(['Name', 'Marks'], dtype='object')

# %%
# Check Data Types of Each Column
df.dtypes
# Out:
# Name     object
# Marks     int64
# dtype: object

# %%
# Access Individual Column
df["Name"]
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df["Marks"]
# Out:
# 0    85
# 1    90
# 2    78
# Name: Marks, dtype: int64

# %%
df.loc[1]
# Out:
# Name      B
# Marks    90
# Name: 1, dtype: object

# %%
# Add New Column
''' If marks 80-90 First Class
If marks>=90 Distinction
If marks<80 Second Class'''
df["Grade"]=["First Class","Distinction","Second Class"]
df
# Out:
#   Name  Marks         Grade
# 0    A     85   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# Update Data in Dataframe
''' Change Marks of Student A to 88'''
df.loc[0,"Marks"]=88
df
# Out:
#   Name  Marks         Grade
# 0    A     88   First Class
# 1    B     90   Distinction
# 2    C     78  Second Class

# %%
# Delete a Column
df.drop("Grade",axis=1 ,inplace=True )
df
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90
# 2    C     78

# %% [markdown]
# #### Perform Basic Statistical Analysis

# %%
Mean = df["Marks"].mean()
Mean
# Out:
# np.float64(85.33333333333333)

# %%
Mode = df["Marks"].mode()
Mode
# Out:
# 0    78
# 1    88
# 2    90
# Name: Marks, dtype: int64

# %%
Min = df["Marks"].min()
Min
# Out:
# 78

# %%
Max = df["Marks"].max()
Max
# Out:
# 90

# %% [markdown]
# #### Apply Conditional Filtering

# %%
''' Dislay Students Scoring More than 80'''
df[df["Marks"]>80]
# Out:
#   Name  Marks
# 0    A     88
# 1    B     90

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'C1':[11,21,np.nan],'C2':[15, np.nan, np.nan],"C3":[10,20,30]})
df1
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %% [markdown]
# #### Conditional Statement

# %%
df1.isna()
# isna = is not a number
# Out:
#       C1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna()
# notna = not not a number
# Out:
#       C1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
df1.isna().sum()
# sum - how many na values are there in each column
# Out:
# C1    1
# C2    2
# C3    0
# dtype: int64

# %%
df1.dropna()
# NaN rows are dropped
# Out:
#      C1    C2  C3
# 0  11.0  15.0  10
