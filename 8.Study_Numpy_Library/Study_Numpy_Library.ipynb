# %% [markdown]
# # Study_Numpy_Library
# ## Experiment - 8

# %% [markdown]
# ### Gunjan Goyal
# ### 25070123048
# ### E&TC-A3

# %%
# Declaration of Numpy
import numpy as np

a = np.array([10,20,30,40])
b = np.array(([1,2,3],[4,5,6]))
print(a)
print(b)
# Out:
# [10 20 30 40]
# [[1 2 3]
#  [4 5 6]]

# %%
# Dimension of Array
print(a.ndim)
print(b.ndim)
# Out:
# 1
# 2

# %%
# Shape
a.shape
# Out:
# (4,)

# %%
# Shape
b.shape
# Out:
# (2, 3)

# %%
# Data Type
a.dtype
b.dtype
# Out:
# dtype('int64')

# %% [markdown]
# #### In-Built Functions Using Numpy

# %%
np.zeros((2,3))
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
np.ones((2,3))
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
np.eye((3))
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
np.arange(1,10,2)
# It gives numbers from 1-10 at a distance of 2
# Out:
# array([1, 3, 5, 7, 9])

# %%
np.linspace(0,1,5)
# 1 is not exclusive here
# 5 is the number of parts
# Out:
# array([0.  , 0.25, 0.5 , 0.75, 1.  ])

# %%
np.linspace(0,1,4)
# Out:
# array([0.        , 0.33333333, 0.66666667, 1.        ])

# %%
print(b*2)
# b*2 is virtual
print(a+5)
# Out:
# [[ 2  4  6]
#  [ 8 10 12]]
# [15 25 35 45]

# %%
a + 5
# Out:
# array([15, 25, 35, 45])

# %%
b + 5
# Out:
# array([[ 6,  7,  8],
#        [ 9, 10, 11]])

# %%
np.mean(a)
# Out:
# np.float64(25.0)

# %%
np.mean(b)
# Out:
# np.float64(3.5)

# %%
np.median(a)
# Out:
# np.float64(25.0)

# %%
np.median(b)
# Out:
# np.float64(3.5)

# %%
np.max(a)
# Out:
# np.int64(40)

# %%
np.max(b)
# Out:
# np.int64(6)

# %%
np.min(a)
# Out:
# np.int64(10)

# %%
np.min(b)
# Out:
# np.int64(1)

# %%
np.sum(a)
# Out:
# np.int64(100)

# %%
np.sum(b)
# Out:
# np.int64(21)
